# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense

from sklearn.metrics import confusion_matrix

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Import Dataset

# %%
dataset = pd.read_csv('/content/drive/MyDrive/dataset/brain_stroke.csv')
dataset
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0             0              1          Yes        Private
# 1       Male  80.0             0              1          Yes        Private
# 2     Female  49.0             0              0          Yes        Private
# 3     Female  79.0             1              0          Yes  Self-employed
# 4       Male  81.0             0              0          Yes        Private
# ...      ...   ...           ...            ...          ...            ...
# 4976    Male  41.0             0              0           No        Private
# 4977    Male  40.0             0              0          Yes        Private
# 4978  Female  45.0             1              0          Yes       Govt_job
# 4979    Male  40.0             0              0          Yes        Private
# 4980  Female  80.0             1              0          Yes        Private
#
#      Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0             Urban             228.69  36.6  formerly smoked       1
# 1             Rural             105.92  32.5     never smoked       1
# 2             Urban             171.23  34.4           smokes       1
# 3             Rural             174.12  24.0     never smoked       1
# 4             Urban             186.21  29.0  formerly smoked       1
# ...             ...                ...   ...              ...     ...
# 4976          Rural              70.15  29.8  formerly smoked       0
# 4977          Urban             191.15  31.1           smokes       0
# 4978          Rural              95.02  31.8           smokes       0
# 4979          Rural              83.94  30.0           smokes       0
# 4980          Urban              83.75  29.1     never smoked       0
#
# [4981 rows x 11 columns]

# %%
# @title avg_glucose_level

from matplotlib import pyplot as plt

# %%
dataset['age'].plot(kind='hist', bins=20, title='age')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
dataset.groupby('gender').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
dataset['avg_glucose_level'].plot(kind='hist', bins=20, title='avg_glucose_level', color = 'g')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# # Drop Unrelated Data

# %%
dataset.drop(['ever_married', 'work_type', 'Residence_type'], axis= 1, inplace = True)

# %%
dataset
# Out:
#       gender   age  hypertension  heart_disease  avg_glucose_level   bmi  \
# 0       Male  67.0             0              1             228.69  36.6
# 1       Male  80.0             0              1             105.92  32.5
# 2     Female  49.0             0              0             171.23  34.4
# 3     Female  79.0             1              0             174.12  24.0
# 4       Male  81.0             0              0             186.21  29.0
# ...      ...   ...           ...            ...                ...   ...
# 4976    Male  41.0             0              0              70.15  29.8
# 4977    Male  40.0             0              0             191.15  31.1
# 4978  Female  45.0             1              0              95.02  31.8
# 4979    Male  40.0             0              0              83.94  30.0
# 4980  Female  80.0             1              0              83.75  29.1
#
#        smoking_status  stroke
# 0     formerly smoked       1
# 1        never smoked       1
# 2              smokes       1
# 3        never smoked       1
# 4     formerly smoked       1
# ...               ...     ...
# 4976  formerly smoked       0
# 4977           smokes       0
# 4978           smokes       0
# 4979           smokes       0
# 4980     never smoked       0
#
# [4981 rows x 8 columns]

# %%
X = dataset.iloc[:, 0:7].values
y = dataset.iloc[:, 7]
print(X)
print(y)
# Out:
# [['Male' 67.0 0 ... 228.69 36.6 'formerly smoked']
#  ['Male' 80.0 0 ... 105.92 32.5 'never smoked']
#  ['Female' 49.0 0 ... 171.23 34.4 'smokes']
#  ...
#  ['Female' 45.0 1 ... 95.02 31.8 'smokes']
#  ['Male' 40.0 0 ... 83.94 30.0 'smokes']
#  ['Female' 80.0 1 ... 83.75 29.1 'never smoked']]
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 4976    0
# 4977    0
# 4978    0
# 4979    0
# 4980    0
# Name: stroke, Length: 4981, dtype: int64

# %% [markdown]
# # Encode Categorical Data

# %%
# Gender
label_encoder = LabelEncoder()
X[:, 0] = label_encoder.fit_transform(X[:, 0])
X
# Out:
# array([[1, 67.0, 0, ..., 228.69, 36.6, 'formerly smoked'],
#        [1, 80.0, 0, ..., 105.92, 32.5, 'never smoked'],
#        [0, 49.0, 0, ..., 171.23, 34.4, 'smokes'],
#        ...,
#        [0, 45.0, 1, ..., 95.02, 31.8, 'smokes'],
#        [1, 40.0, 0, ..., 83.94, 30.0, 'smokes'],
#        [0, 80.0, 1, ..., 83.75, 29.1, 'never smoked']], dtype=object)

# %%
# BMI
bmi_mean = X[:, 5].mean()
print(bmi_mean)
X[:, 5] = np.where(X[:, 5] >= bmi_mean, 1, 0)
print(X)
# Out:
# 28.498173057619002
# [[1 67.0 0 ... 228.69 1 'formerly smoked']
#  [1 80.0 0 ... 105.92 1 'never smoked']
#  [0 49.0 0 ... 171.23 1 'smokes']
#  ...
#  [0 45.0 1 ... 95.02 1 'smokes']
#  [1 40.0 0 ... 83.94 1 'smokes']
#  [0 80.0 1 ... 83.75 1 'never smoked']]

# %%
# Smoking
col_trans = ColumnTransformer(transformers=[('encoder', OneHotEncoder(sparse_output=False), [0])], remainder= 'passthrough')
label_encoder_sm = LabelEncoder()

smk = X[:, 6]

smk = label_encoder_sm.fit_transform(smk)
smk
# Out:
# array([1, 2, 3, ..., 3, 3, 2])

# %%
label_encoder_sm = LabelEncoder()

X[:, 6] = label_encoder_sm.fit_transform(X[:, 6])
X
# Out:
# array([[1, 67.0, 0, ..., 228.69, 1, 1],
#        [1, 80.0, 0, ..., 105.92, 1, 2],
#        [0, 49.0, 0, ..., 171.23, 1, 3],
#        ...,
#        [0, 45.0, 1, ..., 95.02, 1, 3],
#        [1, 40.0, 0, ..., 83.94, 1, 3],
#        [0, 80.0, 1, ..., 83.75, 1, 2]], dtype=object)

# %%
#smk = smk.reshape(-1, 1)
#smk.shape

# %%
#smk = col_trans.fit_transform(smk)

# %%
#smk = smk[:, 1:]
#smk.shape

# %%
#X = X[:, :6]
#X = np.concatenate((X, smk), axis = 1)

# %%
X
# Out:
# array([[1, 67.0, 0, ..., 228.69, 1, 1],
#        [1, 80.0, 0, ..., 105.92, 1, 2],
#        [0, 49.0, 0, ..., 171.23, 1, 3],
#        ...,
#        [0, 45.0, 1, ..., 95.02, 1, 3],
#        [1, 40.0, 0, ..., 83.94, 1, 3],
#        [0, 80.0, 1, ..., 83.75, 1, 2]], dtype=object)

# %%
temp_df = pd.DataFrame(X)
temp_df
# Out:
#       0     1  2  3       4  5  6
# 0     1  67.0  0  1  228.69  1  1
# 1     1  80.0  0  1  105.92  1  2
# 2     0  49.0  0  0  171.23  1  3
# 3     0  79.0  1  0  174.12  0  2
# 4     1  81.0  0  0  186.21  1  1
# ...  ..   ... .. ..     ... .. ..
# 4976  1  41.0  0  0   70.15  1  1
# 4977  1  40.0  0  0  191.15  1  3
# 4978  0  45.0  1  0   95.02  1  3
# 4979  1  40.0  0  0   83.94  1  3
# 4980  0  80.0  1  0   83.75  1  2
#
# [4981 rows x 7 columns]

# %% [markdown]
# # Data Splitting

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# %% [markdown]
# # Building ANN

# %%
classifier = Sequential()

classifier.add(Dense(units = 6, activation = 'relu'))

classifier.add(Dense(units = 6, activation = 'relu'))
classifier.add(Dense(units = 6, activation = 'relu'))
classifier.add(Dense(units = 6, activation = 'relu'))


classifier.add(Dense(units = 1, activation = 'sigmoid'))

classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
X_train = np.asarray(X_train).astype(np.float32)
y_train = np.asarray(y_train).astype(np.float32)

# %% [markdown]
# # Train ANN Model

# %%
hsitory = classifier.fit(X_train, y_train, batch_size = 50, epochs=150)
# Out:
# Epoch 1/150
# 75/75 [==============================] - 3s 4ms/step - loss: 46.4045 - accuracy: 0.0538
# Epoch 2/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.6028 - accuracy: 0.9090
# Epoch 3/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.3304 - accuracy: 0.9494
# Epoch 4/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.2677 - accuracy: 0.9494
# Epoch 5/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.2572 - accuracy: 0.9494
# Epoch 6/150
# 75/75 [==============================] - 0s 3ms/step - loss: 0.2498 - accuracy: 0.9494
# Epoch 7/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.2461 - accuracy: 0.9494
# Epoch 8/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.2425 - accuracy: 0.9494
# Epoch 9/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.2374 - accuracy: 0.9494
# Epoch 10/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.2368 - accuracy: 0.9494
# Epoch 11/150
# 75/75 [==============================] - 0s 3ms/step - loss: 0.2293 - accuracy: 0.9494
# Epoch 12/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.2265 - accuracy: 0.9494
# Epoch 13/150
# 75/75 [==============================] - 0s 3ms/step - loss: 0.2219 - accuracy: 0.9494
# Epoch 14/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.2202 - accuracy: 0.9494
# Epoch 15/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.2139 - accuracy: 0.9494
# Epoch 16/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.2093 - accuracy: 0.9494
# Epoch 17/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.2057 - accuracy: 0.9494
# Epoch 18/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.2003 - accuracy: 0.9494
# Epoch 19/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1959 - accuracy: 0.9494
# Epoch 20/150
# 75/75 [==============================] - 0s 3ms/step - loss: 0.1971 - accuracy: 0.9494
# Epoch 21/150
# 75/75 [==============================] - 0s 3ms/step - loss: 0.1897 - accuracy: 0.9494
# Epoch 22/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1922 - accuracy: 0.9494
# Epoch 23/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1834 - accuracy: 0.9494
# Epoch 24/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1847 - accuracy: 0.9494
# Epoch 25/150
# 75/75 [==============================] - 0s 5ms/step - loss: 0.1780 - accuracy: 0.9494
# Epoch 26/150
# 75/75 [==============================] - 0s 5ms/step - loss: 0.1798 - accuracy: 0.9494
# Epoch 27/150
# 75/75 [==============================] - 0s 5ms/step - loss: 0.1778 - accuracy: 0.9494
# Epoch 28/150
# 75/75 [==============================] - 0s 5ms/step - loss: 0.1733 - accuracy: 0.9494
# Epoch 29/150
# 75/75 [==============================] - 0s 5ms/step - loss: 0.1779 - accuracy: 0.9494
# Epoch 30/150
# 75/75 [==============================] - 0s 5ms/step - loss: 0.1739 - accuracy: 0.9494
# Epoch 31/150
# 75/75 [==============================] - 0s 6ms/step - loss: 0.1725 - accuracy: 0.9494
# Epoch 32/150
# 75/75 [==============================] - 0s 6ms/step - loss: 0.1721 - accuracy: 0.9494
# Epoch 33/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1806 - accuracy: 0.9494
# Epoch 34/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1726 - accuracy: 0.9494
# Epoch 35/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1692 - accuracy: 0.9494
# Epoch 36/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1769 - accuracy: 0.9494
# Epoch 37/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1715 - accuracy: 0.9494
# Epoch 38/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1690 - accuracy: 0.9494
# Epoch 39/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1679 - accuracy: 0.9494
# Epoch 40/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1695 - accuracy: 0.9494
# Epoch 41/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1688 - accuracy: 0.9494
# Epoch 42/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1641 - accuracy: 0.9494
# Epoch 43/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1713 - accuracy: 0.9494
# Epoch 44/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1653 - accuracy: 0.9494
# Epoch 45/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1686 - accuracy: 0.9494
# Epoch 46/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1676 - accuracy: 0.9494
# Epoch 47/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1748 - accuracy: 0.9494
# Epoch 48/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1705 - accuracy: 0.9494
# Epoch 49/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1702 - accuracy: 0.9494
# Epoch 50/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1677 - accuracy: 0.9494
# Epoch 51/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1678 - accuracy: 0.9494
# Epoch 52/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1681 - accuracy: 0.9494
# Epoch 53/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1664 - accuracy: 0.9494
# Epoch 54/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1635 - accuracy: 0.9494
# Epoch 55/150
# 75/75 [==============================] - 0s 3ms/step - loss: 0.1698 - accuracy: 0.9494
# Epoch 56/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1661 - accuracy: 0.9494
# Epoch 57/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1664 - accuracy: 0.9494
# Epoch 58/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1710 - accuracy: 0.9494
# Epoch 59/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1705 - accuracy: 0.9494
# Epoch 60/150
# 75/75 [==============================] - 0s 3ms/step - loss: 0.1672 - accuracy: 0.9494
# Epoch 61/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1707 - accuracy: 0.9494
# Epoch 62/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1651 - accuracy: 0.9494
# Epoch 63/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1633 - accuracy: 0.9494
# Epoch 64/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1711 - accuracy: 0.9494
# Epoch 65/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1650 - accuracy: 0.9494
# Epoch 66/150
# 75/75 [==============================] - 0s 3ms/step - loss: 0.1653 - accuracy: 0.9494
# Epoch 67/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1689 - accuracy: 0.9494
# Epoch 68/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1633 - accuracy: 0.9494
# Epoch 69/150
# 75/75 [==============================] - 0s 6ms/step - loss: 0.1654 - accuracy: 0.9494
# Epoch 70/150
# 75/75 [==============================] - 0s 5ms/step - loss: 0.1667 - accuracy: 0.9494
# Epoch 71/150
# 75/75 [==============================] - 0s 5ms/step - loss: 0.1671 - accuracy: 0.9494
# Epoch 72/150
# 75/75 [==============================] - 0s 5ms/step - loss: 0.1632 - accuracy: 0.9494
# Epoch 73/150
# 75/75 [==============================] - 0s 6ms/step - loss: 0.1646 - accuracy: 0.9494
# Epoch 74/150
# 75/75 [==============================] - 0s 5ms/step - loss: 0.1670 - accuracy: 0.9494
# Epoch 75/150
# 75/75 [==============================] - 0s 6ms/step - loss: 0.1672 - accuracy: 0.9494
# Epoch 76/150
# 75/75 [==============================] - 0s 6ms/step - loss: 0.1652 - accuracy: 0.9494
# Epoch 77/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1711 - accuracy: 0.9494
# Epoch 78/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1634 - accuracy: 0.9494
# Epoch 79/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1691 - accuracy: 0.9494
# Epoch 80/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1646 - accuracy: 0.9494
# Epoch 81/150
# 75/75 [==============================] - 0s 3ms/step - loss: 0.1656 - accuracy: 0.9494
# Epoch 82/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1760 - accuracy: 0.9494
# Epoch 83/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1686 - accuracy: 0.9494
# Epoch 84/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1702 - accuracy: 0.9494
# Epoch 85/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1720 - accuracy: 0.9494
# Epoch 86/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1711 - accuracy: 0.9494
# Epoch 87/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1724 - accuracy: 0.9494
# Epoch 88/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1678 - accuracy: 0.9481
# Epoch 89/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1750 - accuracy: 0.9494
# Epoch 90/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1686 - accuracy: 0.9494
# Epoch 91/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1654 - accuracy: 0.9494
# Epoch 92/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1643 - accuracy: 0.9494
# Epoch 93/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1659 - accuracy: 0.9494
# Epoch 94/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1644 - accuracy: 0.9494
# Epoch 95/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1677 - accuracy: 0.9494
# Epoch 96/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1651 - accuracy: 0.9494
# Epoch 97/150
# 75/75 [==============================] - 0s 3ms/step - loss: 0.1646 - accuracy: 0.9494
# Epoch 98/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1627 - accuracy: 0.9494
# Epoch 99/150
# 75/75 [==============================] - 0s 3ms/step - loss: 0.1640 - accuracy: 0.9494
# Epoch 100/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1627 - accuracy: 0.9494
# Epoch 101/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1637 - accuracy: 0.9494
# Epoch 102/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1672 - accuracy: 0.9494
# Epoch 103/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1681 - accuracy: 0.9494
# Epoch 104/150
# 75/75 [==============================] - 0s 5ms/step - loss: 0.1686 - accuracy: 0.9494
# Epoch 105/150
# 75/75 [==============================] - 0s 7ms/step - loss: 0.1616 - accuracy: 0.9494
# Epoch 106/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1643 - accuracy: 0.9494
# Epoch 107/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1646 - accuracy: 0.9494
# Epoch 108/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1631 - accuracy: 0.9494
# Epoch 109/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1685 - accuracy: 0.9494
# Epoch 110/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1664 - accuracy: 0.9494
# Epoch 111/150
# 75/75 [==============================] - 0s 5ms/step - loss: 0.1632 - accuracy: 0.9494
# Epoch 112/150
# 75/75 [==============================] - 0s 5ms/step - loss: 0.1630 - accuracy: 0.9494
# Epoch 113/150
# 75/75 [==============================] - 0s 6ms/step - loss: 0.1647 - accuracy: 0.9494
# Epoch 114/150
# 75/75 [==============================] - 0s 5ms/step - loss: 0.1636 - accuracy: 0.9494
# Epoch 115/150
# 75/75 [==============================] - 0s 6ms/step - loss: 0.1654 - accuracy: 0.9494
# Epoch 116/150
# 75/75 [==============================] - 0s 5ms/step - loss: 0.1749 - accuracy: 0.9494
# Epoch 117/150
# 75/75 [==============================] - 0s 6ms/step - loss: 0.1647 - accuracy: 0.9494
# Epoch 118/150
# 75/75 [==============================] - 0s 5ms/step - loss: 0.1631 - accuracy: 0.9494
# Epoch 119/150
# 75/75 [==============================] - 0s 5ms/step - loss: 0.1670 - accuracy: 0.9494
# Epoch 120/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1644 - accuracy: 0.9494
# Epoch 121/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1686 - accuracy: 0.9494
# Epoch 122/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1626 - accuracy: 0.9494
# Epoch 123/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1681 - accuracy: 0.9494
# Epoch 124/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1662 - accuracy: 0.9494
# Epoch 125/150
# 75/75 [==============================] - 0s 3ms/step - loss: 0.1683 - accuracy: 0.9494
# Epoch 126/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1626 - accuracy: 0.9494
# Epoch 127/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1625 - accuracy: 0.9494
# Epoch 128/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1633 - accuracy: 0.9494
# Epoch 129/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1621 - accuracy: 0.9494
# Epoch 130/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1656 - accuracy: 0.9475
# Epoch 131/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1698 - accuracy: 0.9494
# Epoch 132/150
# 75/75 [==============================] - 1s 7ms/step - loss: 0.1651 - accuracy: 0.9494
# Epoch 133/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1639 - accuracy: 0.9494
# Epoch 134/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1646 - accuracy: 0.9494
# Epoch 135/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1658 - accuracy: 0.9494
# Epoch 136/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1651 - accuracy: 0.9494
# Epoch 137/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1646 - accuracy: 0.9494
# Epoch 138/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1626 - accuracy: 0.9494
# Epoch 139/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1620 - accuracy: 0.9494
# Epoch 140/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1669 - accuracy: 0.9494
# Epoch 141/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1620 - accuracy: 0.9494
# Epoch 142/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1636 - accuracy: 0.9494
# Epoch 143/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1619 - accuracy: 0.9494
# Epoch 144/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1631 - accuracy: 0.9494
# Epoch 145/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1626 - accuracy: 0.9494
# Epoch 146/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1626 - accuracy: 0.9494
# Epoch 147/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1634 - accuracy: 0.9494
# Epoch 148/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1616 - accuracy: 0.9494
# Epoch 149/150
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1651 - accuracy: 0.9494
# Epoch 150/150
# 75/75 [==============================] - 0s 3ms/step - loss: 0.1632 - accuracy: 0.9494

# %% [markdown]
# # Model Summary

# %%
classifier.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 6)                 48
#
#  dense_1 (Dense)             (None, 6)                 42
#
#  dense_2 (Dense)             (None, 6)                 42
#
#  dense_3 (Dense)             (None, 6)                 42
#
#  dense_4 (Dense)             (None, 1)                 7
#
# =================================================================
# Total params: 181 (724.00 Byte)
# Trainable params: 181 (724.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # Learning Curve

# %%
plt.plot(hsitory.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(hsitory.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(hsitory.history['accuracy'])
plt.plot(hsitory.history['loss'])
plt.title('Learning Curve')
plt.ylabel('')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %% [markdown]
# # Prediction

# %%
# gender	age	hypertension	heart_disease	avg_glucose_level	bmi	smoking_status
test = classifier.predict([[1, 90, 1, 1, 228.69, 1, 2]])
# Out:
# 1/1 [==============================] - 0s 184ms/step

# %%
test
# Out:
# array([[0.20391226]], dtype=float32)

# %% [markdown]
# # Save Model

# %%
classifier.save('ANN.h5')
print("Model has been saved")
# Out:
# Model has been saved
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
tf.saved_model.save(classifier, "./temp_models/ANN_tmp_model")
print("Model has been saved")
# Out:
# Model has been saved

# %%
# !pip install tf2onnx
# Out:
# Collecting tf2onnx
#   Downloading tf2onnx-1.16.1-py3-none-any.whl (455 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 455.8/455.8 kB 3.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.14.1 in /usr/local/lib/python3.10/dist-packages (from tf2onnx) (1.25.2)
# Collecting onnx>=1.4.1 (from tf2onnx)
#   Downloading onnx-1.16.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (15.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 52.4 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from tf2onnx) (2.31.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from tf2onnx) (1.16.0)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.10/dist-packages (from tf2onnx) (24.3.25)
# Requirement already satisfied: protobuf~=3.20 in /usr/local/lib/python3.10/dist-packages (from tf2onnx) (3.20.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->tf2onnx) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->tf2onnx) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->tf2onnx) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->tf2onnx) (2024.2.2)
# Installing collected packages: onnx, tf2onnx
# Successfully installed onnx-1.16.0 tf2onnx-1.16.1

# %%
# !python3 -m tf2onnx.convert --saved-model /content/temp_models/ANN_tmp_model --output "./output_models/ANN_model.onnx"
# Out:
# 2024-04-13 22:53:53.001565: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-13 22:53:53.001614: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-13 22:53:53.002862: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-13 22:53:54.002676: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/lib/python3.10/runpy.py:126: RuntimeWarning: 'tf2onnx.convert' found in sys.modules after import of package 'tf2onnx', but prior to execution of 'tf2onnx.convert'; this may result in unpredictable behaviour
#   warn(RuntimeWarning(msg))
# 2024-04-13 22:53:55.800062: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2024-04-13 22:53:55,801 - WARNING - '--tag' not specified for saved_model. Using --tag serve
# 2024-04-13 22:53:56,052 - INFO - Signatures found in model: [serving_default].
# 2024-04-13 22:53:56,053 - WARNING - '--signature_def' not specified, using first signature: serving_default
# 2024-04-13 22:53:56,053 - INFO - Output names: ['dense_4']
# 2024-04-13 22:53:56,125 - INFO - Using tensorflow=2.15.0, onnx=1.16.0, tf2onnx=1.16.1/15c810
# 2024-04-13 22:53:56,125 - INFO - Using opset <onnx, 15>
# 2024-04-13 22:53:56,130 - INFO - Computed 0 values for constant folding
# 2024-04-13 22:53:56,143 - INFO - Optimizing ONNX model
# 2024-04-13 22:53:56,184 - INFO - After optimization: Identity -2 (2->0)
# 2024-04-13 22:53:56,186 - INFO -
# 2024-04-13 22:53:56,186 - INFO - Successfully converted TensorFlow model /content/temp_models/ANN_tmp_model to ONNX
# 2024-04-13 22:53:56,186 - INFO - Model inputs: ['dense_input']
# 2024-04-13 22:53:56,186 - INFO - Model outputs: ['dense_4']
# 2024-04-13 22:53:56,186 - INFO - ONNX model is saved at ./output_models/ANN_model.onnx
